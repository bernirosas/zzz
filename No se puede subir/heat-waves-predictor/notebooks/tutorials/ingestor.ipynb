# %% [markdown]
# # Ingestor Tutorial

# %% [markdown]
# This notebook shows the usage of the `hw_predictor/components/ingestor` package. Note that the package
# is designed to automatically work with Kubeflow Pipelines, but this will be an introduction to
# better understand how implemented functions can be imported for experimentation use in notebooks.

# %%
# to ensure developed modules are reloaded automatically and there's no need
# to restart the kernel
# %load_ext autoreload
# %autoreload 2

# %%
from os import chdir

# change working directory to project's root path, this improves the interaction
# with the data/ and hw_predictor/ folders
chdir("../..")

# %% [markdown]
# # Imports

# %%
import pandas as pd

import hw_predictor.components.ingestor.src as ing

# %% [markdown]
# # Parameters

# %%
input_path = "data/test/input"
station_id = 330020

# %% [markdown]
# # Code

# %% [markdown]
# Prior to code execution, have to ensure that needed project environment variables are set. This can
# be done with the following command assuming there's already an `.env` file in the project root directory.
#
# ```bash
# export $(cat .env | xargs)
# ```
#
# As of Thu 28/12/2023, the following environment variables are needed:
#
# ```
# METEOCHILE_USER=
# METEOCHILE_API_KEY=
# CDS_API_URL=
# CDS_API_KEY=
# CLUSTER_HOST=
# CLUSTER_USER=
# CLUSTER_PASSWORD=
# ```
# check with Mauro Mendoza (msmendoza@uc.cl) for the values of these variables.

# %% [markdown]
# # Get stations metadata

# %%
ing.meteochile.get_stations_metadata(input_path)
# Out:
# 2023-12-28 10:44:34.417 | INFO     | hw_predictor.components.ingestor.src.meteochile.get_stations_metadata:get_stations_metadata:38 - getting/updating stations metadata...
# 2023-12-28 10:44:34.607 | INFO     | hw_predictor.components.ingestor.src.meteochile.get_stations_metadata:get_stations_metadata:121 - stations metadata successfully saved

# %%
pd.read_parquet(f"{input_path}/stations/metadata.parquet")
# Out:
#                WMO_code ICAO_code                    name  latitude
# national_code
# 170001            85403                  Visviri Tenencia -17.59500  \
# 180005            85406      SCAR   Chacalluta, Arica Ap. -18.35555
# 180017            85405                             Putre -18.20000
# 180018            85407              Defensa Civil, Arica -18.49111
# 180042            85408             Cerro Sombrero, Arica -18.51250
# ...                 ...       ...                     ...       ...
# 950013                0            Base O"Higgins - INACH -63.32167
# 950014                0                 Base Prat - INACH -62.47889
# 950015                0                     Punta Armonía -62.30361
# 950016                0                          Escudero -62.20278
# 950017                0                     Cabo Melville -62.02055
#
#                longitude  altitude  state_id  geographic_zone_id
# national_code
# 170001         -69.47750      4084        15                   0  \
# 180005         -70.34028        50        15                   1
# 180017         -69.56250      3532        15                   2
# 180018         -70.30139        71        15                   1
# 180042         -70.26556       122        15                   1
# ...                  ...       ...       ...                 ...
# 950013         -57.89778         1        12                   1
# 950014         -59.66389         1        12                   1
# 950015         -59.19667         1        12                   1
# 950016         -58.96167         1        12                   1
# 950017         -57.62444       123        12                   1
#
#                                                        data_link
# national_code
# 170001         https://climatologia.meteochile.gob.cl/applica...
# 180005         https://climatologia.meteochile.gob.cl/applica...
# 180017         https://climatologia.meteochile.gob.cl/applica...
# 180018         https://climatologia.meteochile.gob.cl/applica...
# 180042         https://climatologia.meteochile.gob.cl/applica...
# ...                                                          ...
# 950013         https://climatologia.meteochile.gob.cl/applica...
# 950014         https://climatologia.meteochile.gob.cl/applica...
# 950015         https://climatologia.meteochile.gob.cl/applica...
# 950016         https://climatologia.meteochile.gob.cl/applica...
# 950017         https://climatologia.meteochile.gob.cl/applica...
#
# [137 rows x 9 columns]

# %% [markdown]
# # Get Meteochile data

# %%
ing.meteochile.get_daily_temp_history(input_path, station_id)
# Out:
# 2023-12-28 10:44:34.664 | INFO     | hw_predictor.components.ingestor.src.meteochile.get_daily_temp_history:get_daily_temp_history:32 - getting/updating daily temperature history for station 330020...
# 2023-12-28 10:44:34.906 | INFO     | hw_predictor.components.ingestor.src.meteochile.get_daily_temp_history:get_daily_temp_history:108 - daily temperature history for station 330020 successfully saved
#             min_temp  max_temp  mean_temp  cond_mean_temp  hourly_data_count
# date
# 1950-01-01       NaN       NaN       22.8             NaN                3.0  \
# 1950-01-02       NaN       NaN       20.9             NaN                3.0
# 1950-01-03       NaN       NaN       20.3             NaN                3.0
# 1950-01-04       NaN       NaN       22.0             NaN                3.0
# 1950-01-05       NaN       NaN       22.4             NaN                3.0
# ...              ...       ...        ...             ...                ...
# 2023-12-17       9.2      26.3       16.7            16.7               24.0
# 2023-12-18       9.3      30.6       19.4            19.4               24.0
# 2023-12-19      11.6      25.0       18.6            18.6               24.0
# 2023-12-20       8.8      30.8       18.7            18.7               24.0
# 2023-12-21      11.3       NaN       20.7             NaN               23.0
#
#             00_temp  12_temp  min_temp_date  max_temp_date  process_date
# date
# 1950-01-01      NaN      NaN            NaN            NaN           NaN
# 1950-01-02      NaN      NaN            NaN            NaN           NaN
# 1950-01-03      NaN      NaN            NaN            NaN           NaN
# 1950-01-04      NaN      NaN            NaN            NaN           NaN
# 1950-01-05      NaN      NaN            NaN            NaN           NaN
# ...             ...      ...            ...            ...           ...
# 2023-12-17     19.9     13.4         2023.0         2023.0           NaN
# 2023-12-18     22.6     15.9         2023.0         2023.0           NaN
# 2023-12-19     17.3     15.2         2023.0         2023.0           NaN
# 2023-12-20     23.5     14.7         2023.0         2023.0           NaN
# 2023-12-21      NaN     17.7         2023.0            NaN           NaN
#
# [27018 rows x 10 columns]
