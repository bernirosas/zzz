# %%
# change directory to the root of the project
from os import chdir

chdir("../")

# %%
import netCDF4 as nc

# %%
# NetCDF4 file reading
data_path = "data/input/netcdf/SCL_2023.nc"
data = nc.Dataset(data_path)

# %%
data["t2m"][:]
# Out:
# masked_array(
#   data=[[[[261.68388301922766, 263.6686626147524, 262.55272689543887,
#            ..., 272.6639549680656, 275.31645717215997,
#            276.3358546830056],
#           [259.1486057825586, 260.23466062782256, 259.12676975921465,
#            ..., 271.5158398459294, 274.21661115425775,
#            274.8280198078878],
#           [260.00250922174496, 261.08971333139544, 259.7071482744086,
#            ..., 273.2156018735965, 275.7761629267691,
#            276.81509793218555],
#           ...,
#           [269.08399640404735, 269.44716395018855, 268.42546791056986,
#            ..., 282.46488165633116, 280.9513004592808,
#            281.750039207914],
#           [271.35149503865665, 271.96865001421935, 272.2283837655735,
#            ..., 281.3064231547163, 281.3730804891346,
#            281.25815405048235],
#           [272.59614836926073, 274.19362586652727, 274.8923786135331,
#            ..., 281.64315761996744, 281.9534590043286,
# ...
